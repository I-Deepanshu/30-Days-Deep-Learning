# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split

# Example data: Pairs of sentences in source (e.g., English) and target (e.g., French) languages
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("good morning", "bonjour"),
    ("thank you", "merci"),
    ("good night", "bonne nuit")
]

# Splitting input and target texts
input_texts = [pair[0] for pair in data]
target_texts = ["\t" + pair[1] + "\n" for pair in data]  # Add start (\t) and end (\n) tokens for the target

# Tokenization
input_tokenizer = Tokenizer(char_level=True)  # Character-level tokenization
target_tokenizer = Tokenizer(char_level=True)

input_tokenizer.fit_on_texts(input_texts)
target_tokenizer.fit_on_texts(target_texts)

input_sequences = input_tokenizer.texts_to_sequences(input_texts)
target_sequences = target_tokenizer.texts_to_sequences(target_texts)

# Vocabulary sizes
num_encoder_tokens = len(input_tokenizer.word_index) + 1
num_decoder_tokens = len(target_tokenizer.word_index) + 1

# Padding sequences to the same length
max_encoder_seq_length = max([len(seq) for seq in input_sequences])
max_decoder_seq_length = max([len(seq) for seq in target_sequences])

encoder_input_data = pad_sequences(input_sequences, maxlen=max_encoder_seq_length, padding='post')
decoder_input_data = pad_sequences([seq[:-1] for seq in target_sequences], maxlen=max_decoder_seq_length, padding='post')
decoder_target_data = pad_sequences([seq[1:] for seq in target_sequences], maxlen=max_decoder_seq_length, padding='post')

# Convert decoder target data to one-hot encoding
decoder_target_data = np.eye(num_decoder_tokens)[decoder_target_data]

# Define the Encoder-Decoder Model
from tensorflow.keras.layers import Embedding

# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(input_dim=num_encoder_tokens, output_dim=256)(encoder_inputs)
encoder_lstm = LSTM(256, return_state=True)
encoder_outputs, state_h, state_c = encoder_lstm(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(input_dim=num_decoder_tokens, output_dim=256)(decoder_inputs)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Build and compile the model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
model.compile(optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=64,
    epochs=100,
    validation_split=0.2,
)

# Inference setup for testing
# Encoder model for inference
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model for inference
decoder_state_input_h = Input(shape=(256,))
decoder_state_input_c = Input(shape=(256,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding, initial_state=decoder_states_inputs
)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs, [decoder_outputs] + decoder_states
)

# Function to decode sequences
def decode_sequence(input_seq):
    # Encode the input as state vectors
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1 with start character '\t'
    target_seq = np.zeros((1, 1))
    target_seq[0, 0] = target_tokenizer.word_index["\t"]

    # Sampling loop
    stop_condition = False
    decoded_sentence = ""
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = target_tokenizer.index_word[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length or find stop character '\n'
        if sampled_char == "\n" or len(decoded_sentence) > max_decoder_seq_length:
            stop_condition = True

        # Update the target sequence (of length 1)
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence

# Test the model
for seq_index in range(len(input_texts)):
    input_seq = encoder_input_data[seq_index : seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print(f"Input: {input_texts[seq_index]} -> Predicted translation: {decoded_sentence}")
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - accuracy: 0.1167 - loss: 2.8834 - val_accuracy: 0.2667 - val_loss: 2.8108
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4000 - loss: 2.7339 - val_accuracy: 0.2667 - val_loss: 2.7031
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4000 - loss: 2.5182 - val_accuracy: 0.2667 - val_loss: 2.4747
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4000 - loss: 2.1213 - val_accuracy: 0.2667 - val_loss: 2.3543
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4000 - loss: 1.9165 - val_accuracy: 0.2667 - val_loss: 2.3232
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4000 - loss: 1.9135 - val_accuracy: 0.2667 - val_loss: 2.2709
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.4000 - loss: 1.8164 - val_accuracy: 0.2667 - val_loss: 2.2264
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.4000 - loss: 1.7872 - val_accuracy: 0.2667 - val_loss: 2.2419
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4167 - loss: 1.7577 - val_accuracy: 0.3333 - val_loss: 2.1762
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4500 - loss: 1.7348 - val_accuracy: 0.3333 - val_loss: 2.3014
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4500 - loss: 1.7227 - val_accuracy: 0.3333 - val_loss: 2.1821
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4833 - loss: 1.7779 - val_accuracy: 0.3333 - val_loss: 2.2901
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4500 - loss: 1.6886 - val_accuracy: 0.3333 - val_loss: 2.1271
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4500 - loss: 1.6538 - val_accuracy: 0.3333 - val_loss: 2.1898
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4500 - loss: 1.6052 - val_accuracy: 0.3333 - val_loss: 2.0514
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4833 - loss: 1.5670 - val_accuracy: 0.3333 - val_loss: 2.3604
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4667 - loss: 1.5667 - val_accuracy: 0.4000 - val_loss: 2.0782
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4833 - loss: 1.6857 - val_accuracy: 0.3333 - val_loss: 2.1773
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4667 - loss: 1.5193 - val_accuracy: 0.3333 - val_loss: 2.0803
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4833 - loss: 1.4435 - val_accuracy: 0.3333 - val_loss: 2.0565
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.4833 - loss: 1.3920 - val_accuracy: 0.3333 - val_loss: 2.0227
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4833 - loss: 1.3469 - val_accuracy: 0.3333 - val_loss: 2.0265
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4833 - loss: 1.3033 - val_accuracy: 0.4000 - val_loss: 1.9847
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5667 - loss: 1.2617 - val_accuracy: 0.4000 - val_loss: 2.0686
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.5500 - loss: 1.2238 - val_accuracy: 0.4667 - val_loss: 1.8586
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.6500 - loss: 1.2124 - val_accuracy: 0.4000 - val_loss: 2.6936
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4833 - loss: 1.3603 - val_accuracy: 0.4667 - val_loss: 1.8865
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5667 - loss: 1.4544 - val_accuracy: 0.4000 - val_loss: 2.1628
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.5333 - loss: 1.2414 - val_accuracy: 0.4667 - val_loss: 1.9367
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6500 - loss: 1.1303 - val_accuracy: 0.4667 - val_loss: 1.9813
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6500 - loss: 1.0981 - val_accuracy: 0.4667 - val_loss: 1.9621
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6500 - loss: 1.0687 - val_accuracy: 0.4667 - val_loss: 2.0141
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6500 - loss: 1.0417 - val_accuracy: 0.4667 - val_loss: 1.9877
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.6500 - loss: 1.0172 - val_accuracy: 0.4000 - val_loss: 2.1070
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6333 - loss: 1.0092 - val_accuracy: 0.4667 - val_loss: 1.9818
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.5667 - loss: 1.0439 - val_accuracy: 0.4000 - val_loss: 2.3195
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.5667 - loss: 1.1696 - val_accuracy: 0.4667 - val_loss: 1.8493
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6333 - loss: 0.9705 - val_accuracy: 0.4000 - val_loss: 2.2899
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6000 - loss: 0.9648 - val_accuracy: 0.4667 - val_loss: 1.8549
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6667 - loss: 0.9380 - val_accuracy: 0.4000 - val_loss: 2.4494
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6167 - loss: 0.9412 - val_accuracy: 0.4667 - val_loss: 1.9666
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6667 - loss: 0.8977 - val_accuracy: 0.4000 - val_loss: 2.4091
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6167 - loss: 0.8781 - val_accuracy: 0.4667 - val_loss: 2.0746
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.6833 - loss: 0.8448 - val_accuracy: 0.4000 - val_loss: 2.4485
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6167 - loss: 0.8398 - val_accuracy: 0.4667 - val_loss: 2.1639
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6833 - loss: 0.8169 - val_accuracy: 0.4667 - val_loss: 2.5065
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.6000 - loss: 0.8437 - val_accuracy: 0.4667 - val_loss: 2.2245
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.8007 - val_accuracy: 0.4667 - val_loss: 2.3378
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6167 - loss: 0.8233 - val_accuracy: 0.4667 - val_loss: 2.2634
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7667 - loss: 0.7220 - val_accuracy: 0.4667 - val_loss: 2.4679
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7667 - loss: 0.7038 - val_accuracy: 0.5333 - val_loss: 2.2574
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8000 - loss: 0.6866 - val_accuracy: 0.4667 - val_loss: 2.8592
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.6833 - loss: 0.7531 - val_accuracy: 0.5333 - val_loss: 2.0463
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7333 - loss: 0.8125 - val_accuracy: 0.4000 - val_loss: 2.7916
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.6667 - loss: 0.7770 - val_accuracy: 0.5333 - val_loss: 2.4803
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8000 - loss: 0.6541 - val_accuracy: 0.5333 - val_loss: 2.5175
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8333 - loss: 0.6232 - val_accuracy: 0.5333 - val_loss: 2.4442
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.8667 - loss: 0.5815 - val_accuracy: 0.5333 - val_loss: 2.6057
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8000 - loss: 0.5737 - val_accuracy: 0.5333 - val_loss: 2.4449
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8333 - loss: 0.5703 - val_accuracy: 0.4667 - val_loss: 2.7130
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7167 - loss: 0.6117 - val_accuracy: 0.5333 - val_loss: 2.3780
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8167 - loss: 0.5883 - val_accuracy: 0.5333 - val_loss: 2.8839
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7333 - loss: 0.6408 - val_accuracy: 0.5333 - val_loss: 2.4123
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8167 - loss: 0.5860 - val_accuracy: 0.5333 - val_loss: 2.7884
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.7500 - loss: 0.5979 - val_accuracy: 0.5333 - val_loss: 2.3262
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8833 - loss: 0.5097 - val_accuracy: 0.5333 - val_loss: 2.5423
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8667 - loss: 0.4585 - val_accuracy: 0.5333 - val_loss: 2.6034
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9333 - loss: 0.4345 - val_accuracy: 0.5333 - val_loss: 2.6431
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9000 - loss: 0.4255 - val_accuracy: 0.5333 - val_loss: 2.6301
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9333 - loss: 0.4166 - val_accuracy: 0.5333 - val_loss: 2.7697
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8333 - loss: 0.4362 - val_accuracy: 0.5333 - val_loss: 2.5813
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8333 - loss: 0.4590 - val_accuracy: 0.5333 - val_loss: 2.9845
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.7333 - loss: 0.5505 - val_accuracy: 0.5333 - val_loss: 2.4859
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8000 - loss: 0.4757 - val_accuracy: 0.5333 - val_loss: 2.9181
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8667 - loss: 0.4676 - val_accuracy: 0.5333 - val_loss: 2.4415
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8667 - loss: 0.3853 - val_accuracy: 0.5333 - val_loss: 2.7272
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9333 - loss: 0.3459 - val_accuracy: 0.5333 - val_loss: 2.6284
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9167 - loss: 0.3217 - val_accuracy: 0.5333 - val_loss: 2.7447
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9500 - loss: 0.3085 - val_accuracy: 0.5333 - val_loss: 2.6911
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9333 - loss: 0.2973 - val_accuracy: 0.5333 - val_loss: 2.7881
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9500 - loss: 0.2904 - val_accuracy: 0.5333 - val_loss: 2.7172
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9500 - loss: 0.2878 - val_accuracy: 0.5333 - val_loss: 2.8537
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9167 - loss: 0.3064 - val_accuracy: 0.5333 - val_loss: 2.6966
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9000 - loss: 0.3415 - val_accuracy: 0.5333 - val_loss: 2.9493
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.8167 - loss: 0.4616 - val_accuracy: 0.5333 - val_loss: 2.6871
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8500 - loss: 0.4125 - val_accuracy: 0.5333 - val_loss: 2.6698
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8333 - loss: 0.4267 - val_accuracy: 0.5333 - val_loss: 2.5113
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9500 - loss: 0.2697 - val_accuracy: 0.5333 - val_loss: 2.8113
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9667 - loss: 0.2439 - val_accuracy: 0.5333 - val_loss: 2.6686
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.9667 - loss: 0.2335 - val_accuracy: 0.5333 - val_loss: 2.8108
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9500 - loss: 0.2295 - val_accuracy: 0.5333 - val_loss: 2.6616
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9667 - loss: 0.2249 - val_accuracy: 0.5333 - val_loss: 2.8540
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.9333 - loss: 0.2252 - val_accuracy: 0.5333 - val_loss: 2.6741
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9667 - loss: 0.2209 - val_accuracy: 0.5333 - val_loss: 2.8971
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9333 - loss: 0.2272 - val_accuracy: 0.5333 - val_loss: 2.7001
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9667 - loss: 0.2196 - val_accuracy: 0.5333 - val_loss: 2.9137
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9167 - loss: 0.2316 - val_accuracy: 0.5333 - val_loss: 2.7418
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9500 - loss: 0.2188 - val_accuracy: 0.5333 - val_loss: 2.9158
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.9167 - loss: 0.2335 - val_accuracy: 0.5333 - val_loss: 2.7654
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9500 - loss: 0.2068 - val_accuracy: 0.5333 - val_loss: 2.9331
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Input: hello -> Predicted translation: bonjour
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Input: how are you -> Predicted translation: comment çaa
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Input: good morning -> Predicted translation: bonjour
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Input: thank you -> Predicted translation: merci
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# Input: good night -> Predicted translation: bonjour
