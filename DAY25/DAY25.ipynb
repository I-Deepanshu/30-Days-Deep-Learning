# %%
import torch
import cv2
import matplotlib.pyplot as plt
# Load YOLOv5 pre-trained model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Load an image
image_path = '/Users/deepa/Downloads/street.jpg'
image = cv2.imread(image_path)
# Perform object detection
results = model(image)
# Show results
results.show()
# Save detected objects
results.save(save_dir='/Users/deepa/Downloads/ooooo.png')
# Out:
# Using cache found in C:\Users\deepa/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-9-29 Python-3.12.6 torch-2.4.1+cu124 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# C:\Users\deepa/.cache\torch\hub\ultralytics_yolov5_master\models\common.py:892: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# <PIL.Image.Image image mode=RGB size=386x131>
# Saved 1 image to \Users\deepa\Downloads\ooooo.png
