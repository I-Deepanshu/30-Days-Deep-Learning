# %% [markdown]
# ***2. Object Detection***

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /Users/raghavgarg/Downloads/yolov5
# ...

# %%
from PIL import Image
from IPython.display import display
import os
import torch 

# Load YOLOv5 pre-trained model
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')

# Replace this with the path to your local image
img = '/Users/raghavgarg/Downloads/archive (1)/seg_pred/seg_pred/3.jpg'  # Absolute path to your image

# Run the YOLOv5 model
results = model(img)
results.save()  # Save predictions locally

# Dynamically find the latest 'exp' folder in runs/detect
save_dir = 'runs/detect'
latest_exp = sorted(os.listdir(save_dir))[-1]  # Most recent 'exp' folder
output_path = os.path.join(save_dir, latest_exp, os.listdir(os.path.join(save_dir, latest_exp))[0])

# Print the output path
print("Output image saved to:", output_path)

# Display the processed image
display(Image.open(output_path))
# Out:
# Using cache found in /Users/raghavgarg/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-6-3 Python-3.12.4 torch-2.4.1 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...
# /Users/raghavgarg/.cache/torch/hub/ultralytics_yolov5_master/models/common.py:869: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with amp.autocast(autocast):
# Saved 1 image to runs/detect/exp
# Output image saved to: runs/detect/exp/3.jpg
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=150x150>
